# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('startup_funding.csv',encoding='utf-8',skipinitialspace=True)

# %%
data
# Out:
#        SNo        Date       StartupName   IndustryVertical  \
# 0        0  01/08/2017          TouchKin         Technology
# 1        1  02/08/2017           Ethinos         Technology
# 2        2  02/08/2017      Leverage Edu  Consumer Internet
# 3        3  02/08/2017              Zepo  Consumer Internet
# 4        4  02/08/2017      Click2Clinic  Consumer Internet
# ...    ...         ...               ...                ...
# 2367  2367  29/01/2015        Printvenue                NaN
# 2368  2368  29/01/2015          Graphene                NaN
# 2369  2369  30/01/2015    Mad Street Den                NaN
# 2370  2370  30/01/2015         Simplotel                NaN
# 2371  2371  31/01/2015  couponmachine.in                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# 2     Online platform for Higher Education Services    New Delhi
# 3                            DIY Ecommerce platform       Mumbai
# 4                     healthcare service aggregator    Hyderabad
# ...                                             ...          ...
# 2367                                            NaN          NaN
# 2368                                            NaN          NaN
# 2369                                            NaN          NaN
# 2370                                            NaN          NaN
# 2371                                            NaN          NaN
#
#                                           InvestorsName  InvestmentType  \
# 0                                           Kae Capital  Private Equity
# 1                            Triton Investment Advisors  Private Equity
# 2     Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3     Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                        Narottam Thudi, Shireesh Palle    Seed Funding
# ...                                                 ...             ...
# 2367                        Asia Pacific Internet Group  Private Equity
# 2368                                     KARSEMVEN Fund  Private Equity
# 2369                     Exfinity Fund, GrowX Ventures.  Private Equity
# 2370                                         MakeMyTrip  Private Equity
# 2371                  UK based Group of Angel Investors    Seed Funding
#
#      AmountInUSD                            Remarks
# 0      1,300,000                                NaN
# 1            NaN                                NaN
# 2            NaN                                NaN
# 3        500,000                                NaN
# 4        850,000                                NaN
# ...          ...                                ...
# 2367   4,500,000                                NaN
# 2368     825,000                Govt backed VC Fund
# 2369   1,500,000                                NaN
# 2370         NaN  Strategic Funding, Minority stake
# 2371     140,000                                NaN
#
# [2372 rows x 10 columns]

# %%
data['year']=[int(float(i[-4:])) for i in data['Date']]
data
# Out:
#        SNo        Date       StartupName   IndustryVertical  \
# 0        0  01/08/2017          TouchKin         Technology
# 1        1  02/08/2017           Ethinos         Technology
# 2        2  02/08/2017      Leverage Edu  Consumer Internet
# 3        3  02/08/2017              Zepo  Consumer Internet
# 4        4  02/08/2017      Click2Clinic  Consumer Internet
# ...    ...         ...               ...                ...
# 2367  2367  29/01/2015        Printvenue                NaN
# 2368  2368  29/01/2015          Graphene                NaN
# 2369  2369  30/01/2015    Mad Street Den                NaN
# 2370  2370  30/01/2015         Simplotel                NaN
# 2371  2371  31/01/2015  couponmachine.in                NaN
#
#                                         SubVertical CityLocation  \
# 0                          Predictive Care Platform    Bangalore
# 1                          Digital Marketing Agency       Mumbai
# 2     Online platform for Higher Education Services    New Delhi
# 3                            DIY Ecommerce platform       Mumbai
# 4                     healthcare service aggregator    Hyderabad
# ...                                             ...          ...
# 2367                                            NaN          NaN
# 2368                                            NaN          NaN
# 2369                                            NaN          NaN
# 2370                                            NaN          NaN
# 2371                                            NaN          NaN
#
#                                           InvestorsName  InvestmentType  \
# 0                                           Kae Capital  Private Equity
# 1                            Triton Investment Advisors  Private Equity
# 2     Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# 3     Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...    Seed Funding
# 4                        Narottam Thudi, Shireesh Palle    Seed Funding
# ...                                                 ...             ...
# 2367                        Asia Pacific Internet Group  Private Equity
# 2368                                     KARSEMVEN Fund  Private Equity
# 2369                     Exfinity Fund, GrowX Ventures.  Private Equity
# 2370                                         MakeMyTrip  Private Equity
# 2371                  UK based Group of Angel Investors    Seed Funding
#
#      AmountInUSD                            Remarks  year
# 0      1,300,000                                NaN  2017
# 1            NaN                                NaN  2017
# 2            NaN                                NaN  2017
# 3        500,000                                NaN  2017
# 4        850,000                                NaN  2017
# ...          ...                                ...   ...
# 2367   4,500,000                                NaN  2015
# 2368     825,000                Govt backed VC Fund  2015
# 2369   1,500,000                                NaN  2015
# 2370         NaN  Strategic Funding, Minority stake  2015
# 2371     140,000                                NaN  2015
#
# [2372 rows x 11 columns]

# %%
#yearwise funding
yr=data['year'].value_counts()
print(yr)
yr.sort_index(inplace=True)
print(yr)
# Out:
# 2016    993
# 2015    936
# 2017    443
# Name: year, dtype: int64
# 2015    936
# 2016    993
# 2017    443
# Name: year, dtype: int64

# %%
#Top Indian Cities
data['CityLocation']=data['CityLocation'].replace('bangalore','Bangalore')
data['CityLocation']=data['CityLocation'].replace('Delhi','New Delhi')

def correct(string):
    string=str(string)
    return string.split('/')[0].strip()
data['CityLocation']=data['CityLocation'].apply(correct)

array=data['CityLocation'].value_counts()
x=array.index
y=array.values
a=[]
b=[]
for i in range(11):
    if x[i]!='nan':
        print(x[i],y[i])
        a.append(x[i])
        b.append(y[i])

plt.pie(b,labels=a)
plt.show()
# Out:
# Bangalore 635
# Mumbai 449
# New Delhi 389
# Gurgaon 241
# Pune 91
# Noida 79
# Hyderabad 77
# Chennai 67
# Ahmedabad 35
# Jaipur 25

# %%
#Funding amount

data.dropna(inplace=True,subset=['AmountInUSD'])
data.dropna(inplace=True,subset=['CityLocation'])

def correct(string):
    string=str(string)
    return string.split('/')[0].strip()
data['CityLocation']=data['CityLocation'].apply(correct)
data['CityLocation']=data['CityLocation'].replace('bangalore','Bangalore')
data['CityLocation']=data['CityLocation'].replace('Delhi','New Delhi')


data['AmountInUSD']=data['AmountInUSD'].apply(lambda x: float(str(x).replace(',','')))


c = data.groupby("CityLocation")['AmountInUSD'].sum().sort_values(ascending = False)[:10]
d = c.index
e = c.values

a=[]
b=[]

df={}
for i in range(len(c)):
    df[d[i]]=(e[i]/sum(e))*100
    a.append(d[i])
    b.append(e[i])
for i,j in df.items():
    print(i,'{:.2f}'.format(j))

plt.pie(b, labels = a, autopct = "%.2f%%")
plt.show()
# Out:
# Bangalore 46.33
# New Delhi 15.50
# Mumbai 12.95
# Gurgaon 11.38
# nan 7.00
# Chennai 2.26
# Pune 2.02
# Hyderabad 1.07
# Noida 0.94
# Ahmedabad 0.54

# %%
#Investment Type
data.dropna(inplace = True,subset=['AmountInUSD'])
data["AmountInUSD"] = data["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))

data.dropna(inplace = True,subset=['InvestmentType'])
data['InvestmentType'].replace("Crowd funding", 'Crowd Funding', inplace = True)
data['InvestmentType'].replace('PrivateEquity', 'Private Equity', inplace = True)
data['InvestmentType'].replace('SeedFunding', 'Seed Funding', inplace = True)


c = data.groupby("InvestmentType")['AmountInUSD'].sum().sort_values(ascending = False)
d = c.index
e = c.values

df={}
for i in range(len(d)):
    df[d[i]]=(e[i]/sum(e))*100
for i,j in df.items():
    print(i,'{:.2f}'.format(j))

plt.pie(e, labels = d, autopct = "%.2f%%")
plt.show()
# Out:
# Private Equity 98.15
# Seed Funding 1.81
# Debt Funding 0.04
# Crowd Funding 0.00

# %%
#Top Industries
d=dict()
for i in data['IndustryVertical']:
    d[i]=d.get(i,0)+1
    
data.dropna(inplace = True,subset=['AmountInUSD'])
data["AmountInUSD"] = data["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))

data.dropna(inplace=True,subset=['IndustryVertical'])
data["IndustryVertical"].replace('eCommerce','Ecommerce', inplace = True)
data['IndustryVertical'].replace("ECommerce","Ecommerce", inplace = True)
data['IndustryVertical'].replace("ecommerce","Ecommerce", inplace = True)

c = data.groupby("IndustryVertical")['AmountInUSD'].sum().sort_values(ascending = False)[:5]
d = c.index
e = c.values

for i in range(len(d)):
    k=((e[i]/sum(e))*100)
    print(d[i],'{:.2f}'.format(k))
# Out:
# Ecommerce 40.53
# Consumer Internet 35.95
# Technology 10.45
# Online Marketplace 6.63
# E-Commerce & M-Commerce platform 6.44

# %%
#Top Startups

data['StartupName'].replace('Olacabs','Ola',inplace=True) 
data['StartupName'].replace('Ola Cabs','Ola',inplace=True) 
data['StartupName'].replace('Flipkart.com','Flipkart',inplace=True) 
data['StartupName'].replace('Paytm Marketplace','Paytm',inplace=True) 
data['StartupName'].replace('Oyo Rooms','Oyo',inplace=True) 
data['StartupName'].replace('Oyorooms','Oyo',inplace=True) 
data['StartupName'].replace('OyoRooms','Oyo',inplace=True) 
data['StartupName'].replace('OYO Rooms','Oyo',inplace=True) 

data.dropna(inplace = True,subset=['AmountInUSD'])
data["AmountInUSD"] = data["AmountInUSD"].apply(lambda x: float(str(x).replace(",","")))

c = data.groupby("StartupName")['AmountInUSD'].sum().sort_values(ascending = False)[:5]
d = c.index

for i in range(5):
    print(d[i])
# Out:
# Paytm
# Flipkart
# Ola
# Snapdeal
# Oyo

# %%
#funding rounds

data['StartupName'].replace('Olacabs','Ola',inplace=True) 
data['StartupName'].replace('Ola Cabs','Ola',inplace=True) 
data['StartupName'].replace('Flipkart.com','Flipkart',inplace=True) 
data['StartupName'].replace('Paytm Marketplace','Paytm',inplace=True) 
data['StartupName'].replace('Oyo Rooms','Oyo',inplace=True) 
data['StartupName'].replace('Oyorooms','Oyo',inplace=True) 
data['StartupName'].replace('OyoRooms','Oyo',inplace=True) 
data['StartupName'].replace('OYO Rooms','Oyo',inplace=True) 

data['count']=1
c = data.groupby("StartupName")['count'].sum().sort_values(ascending = False)[:5]
d = c.index
e = c.values

for i in range(len(d)):
    print(d[i],e[i])
# Out:
# Ola 8
# Swiggy 7
# Flipkart 5
# UrbanClap 5
# Oyo 5

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 21>()
#      18 data.dropna(inplace=True,subset=['InvestorsName'])
#      19 dic=set_dictionary(data['InvestorsName'])
# ---> 21 k=sorted(dic.items(),key=operator.itemgetter(1),reverse=True)[:1]
#      22 print(k[0][0],k[0][1])
#
# NameError: name 'operator' is not defined
